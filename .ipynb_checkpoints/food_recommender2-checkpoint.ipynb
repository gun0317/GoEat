# %% [markdown]
# Food Recommender
# ==

# %% [markdown]
# Import Modules

# %%
#import modules
import numpy as np
import pandas as pd
import GoEat
from GoEatWebCrawler import GoEatWebCrawler
from collections import Counter
from konlpy.tag import Hannanum
from konlpy.tag import Kkma
from konlpy.utils import concordance, pprint
import scipy
import sklearn
import konlpy
import re
import pickle

# %%
#set seed to get constant data
np.random.seed(10)

# %%
#import data
df_user_info = pd.read_csv('data\\info\\df_user_info.csv')
df_user_detail =pd.read_csv('data\\info\\df_user_detail.csv')
food_df = pd.read_csv('data\\info\\food_df.csv')
food_detail_df = pd.read_csv('data\\info\\food_detail_df.csv')
interactions_df = pd.read_csv('data\\info\\interactions_df.csv')

# %%
#save data
df_user_info.to_csv('data\\info\\df_user_info.csv',index=False)
df_user_detail.to_csv('data\\info\\df_user_detail.csv',index=False)
food_df.to_csv('data\\info\\food_df.csv',index=False)
food_detail_df.to_csv('data\\info\\food_detail_df.csv',index=False)
interactions_df.to_csv('data\\info\\interactions_df.csv',index=False)

# %%
# smoothen user preference
interactions_full_df = interactions_df \
                    .groupby(['userId', 'foodId'])['eventStrength'].mean() \
                    .apply(GoEat.smooth_user_preference).reset_index()

# %%
#split test and test set
interactions_train_df, interactions_test_df = \
GoEat.interactions_train_test_split(interactions_full_df, test_size=0.20)
# Out:
# # interactions on Train set: 8280
# # interactions on Test set: 2070

# %%
cf_preds_df = GoEat.users_items_svd(interactions_train_df, nfactors = 20)

# %%
with open('data\\stopwords-ko.txt', 'r',encoding='utf-8') as f:
    lines = f.readlines()
    stopwords_ko = list(map(lambda x: x.rstrip('\n'),lines))

# %%
tfidf_matrix, tfidf_feature_names = GoEat.tfidf_vectorizer(food_detail_df,'foodRecipeNoun',stopwords_ko )

# %%
#save tfidf
with open('tfidf.pickle', 'wb') as f:
    pickle.dump([tfidf_matrix, tfidf_feature_names], f)

# %%
#load tfidf
with open('tfidf.pickle', 'rb') as f:
    tfidf_matrix, tfidf_feature_names = pickle.load(f)

# %%
builder= GoEat.user_profiles_builder()
user_profiles = builder.build_users_profiles(interactions_df,food_df,tfidf_matrix)

# %%
myprofile = user_profiles[1]
print(myprofile.shape)
df_profile = pd.DataFrame(sorted(zip(tfidf_feature_names, 
                        myprofile.flatten().tolist()), key=lambda x: -x[1]),
             columns=['token', 'relevance'])
df_profile.head(10)
# Out:
# (1, 785)
#   token  relevance
# 0   삼겹살   0.232535
# 1   불고기   0.198848
# 2    소금   0.166053
# 3   적당량   0.161354
# 4    계란   0.159243
# 5   양념장   0.149799
# 6  돼지고기   0.143454
# 7    대파   0.140219
# 8    소스   0.135484
# 9    야채   0.130621

# %%
cf_model = GoEat.CFRecommender(cf_preds_df, food_df)
cb_model = GoEat.CBRecommender(food_df,user_profiles,tfidf_matrix)
hybrid_model = GoEat.HybridRecommender(cb_model, cf_model, food_df)
model_evaluator = GoEat.ModelEvaluator(interactions_full_df,interactions_train_df,interactions_test_df,food_df,17)

# %%
cf_model.recommend_items(1,topn=10,verbose=True)
# Out:
#    recStrength  foodId foodName
# 0     2.808058      22      냉모밀
# 1     2.415330      39       컵밥
# 2     2.249285       0      볶음밥
# 3     2.125537      38    오므라이스
# 4     2.001176      10     잔치국수
# 5     1.962086      41      햄버거
# 6     1.939422      43       치킨
# 7     1.932477      34       커리
# 8     1.923459       4     닭도리탕
# 9     1.905082       9       족발

# %%
print('Evaluating Content-Based Filtering model...')
cb_global_metrics, cb_detailed_results_df = model_evaluator.evaluate_model(cb_model)
print('\nGlobal metrics:\n%s' % cb_global_metrics)
cb_detailed_results_df.head()
# Out:
# Evaluating Content-Based Filtering model...
# 217 users processed
#
# Global metrics:
# {'modelName': 'Content-Based', 'recall@5': 0.9144927536231884, 'recall@10': 0.9816425120772947, 'ndcg@5': 0.9219679497210954, 'ndcg@10': 0.8903263690204752}
#      _person_id  hits@10_count  hits@5_count  interacted_count   ndcg@10  \
# 2             2             18            18                18  0.958054
# 214         214             18            15                18  0.893269
# 199         199             18            17                18  0.870861
# 140         140             17            15                17  0.861280
# 139         139             16            16                16  0.989631
#
#        ndcg@5  recall@10  recall@5
# 2    0.951796        1.0  1.000000
# 214  0.915196        1.0  0.833333
# 199  0.921648        1.0  0.944444
# 140  0.946623        1.0  0.882353
# 139  0.985715        1.0  1.000000

# %%
print('Evaluating Collaborative Filtering model...')
cf_global_metrics, cf_detailed_results_df = model_evaluator.evaluate_model(cf_model)
print('\nGlobal metrics:\n%s' % cf_global_metrics)
cf_detailed_results_df.head(10)
# Out:
# Evaluating Collaborative Filtering model...
# 217 users processed
#
# Global metrics:
# {'modelName': 'Collaborative Filtering', 'recall@5': 0.9188405797101449, 'recall@10': 0.9599033816425121, 'ndcg@5': 0.8557984273426588, 'ndcg@10': 0.8613959108667257}
#      _person_id  hits@10_count  hits@5_count  interacted_count   ndcg@10  \
# 109         215             11            10                12  0.810363
# 16          193             11            11                12  0.958169
# 71          209             12            12                12  0.939035
# 153         180             12            12                12  0.982574
# 171         201             11            11                12  0.658050
# 89          177             12            11                12  0.842404
# 59          195             12            12                12  0.838156
# 92          212             12            12                12  0.886284
# 56          186             11            11                12  0.932469
# 179         214             12            10                12  0.929467
#
#        ndcg@5  recall@10  recall@5
# 109  0.882020   0.916667  0.833333
# 16   0.955385   0.916667  0.916667
# 71   0.983235   1.000000  1.000000
# 153  0.975439   1.000000  1.000000
# 171  0.646092   0.916667  0.916667
# 89   0.816293   1.000000  0.916667
# 59   0.885291   1.000000  1.000000
# 92   0.865374   1.000000  1.000000
# 56   0.959913   0.916667  0.916667
# 179  0.901534   1.000000  0.833333

# %%
print('Evaluating Hybrid Filtering model...')
cf_global_metrics, cf_detailed_results_df = model_evaluator.evaluate_model(hybrid_model)
print('\nGlobal metrics:\n%s' % cf_global_metrics)
cf_detailed_results_df.head(10)
# Out:
# Evaluating Hybrid Filtering model...
# 217 users processed
#
# Global metrics:
# {'modelName': 'Hybrid', 'recall@5': 0.9371980676328503, 'recall@10': 0.9603864734299516, 'ndcg@5': 0.9257944694587348, 'ndcg@10': 0.9182311915678388}
#      _person_id  hits@10_count  hits@5_count  interacted_count   ndcg@10  \
# 109         215             11            11                12  0.819887
# 16          193             11            11                12  0.964479
# 71          209             12            12                12  0.939563
# 153         180             12            12                12  0.991780
# 171         201             11            11                12  0.790465
# 89          177             11            11                12  0.915070
# 59          195             12            12                12  0.906268
# 92          212             12            12                12  0.936384
# 56          186             11            11                12  0.977711
# 179         214             11            10                12  0.958302
#
#        ndcg@5  recall@10  recall@5
# 109  0.889850   0.916667  0.916667
# 16   0.973410   0.916667  0.916667
# 71   0.961072   1.000000  1.000000
# 153  0.975439   1.000000  1.000000
# 171  0.763778   0.916667  0.916667
# 89   0.862920   0.916667  0.916667
# 59   0.880499   1.000000  1.000000
# 92   0.893079   1.000000  1.000000
# 56   0.968231   0.916667  0.916667
# 179  0.966807   0.916667  0.833333

# %%
import os, sys

class HiddenPrints:
    def __enter__(self):
        self._original_stdout = sys.stdout
        sys.stdout = open(os.devnull, 'w')

    def __exit__(self, exc_type, exc_val, exc_tb):
        sys.stdout.close()
        sys.stdout = self._original_stdout

# %%
from sklearn.model_selection import KFold
import time

cf_model = GoEat.CFRecommender(cf_preds_df, food_df)

nfactors = list(range(5,76,5))
metrics = ['recall@5','recall@10','ndcg@5','ndcg@10']

total_length =len(nfactors) * 5

accuracies = np.zeros((len(nfactors),len(metrics),5))

start_time = time.time()

count = 0

cv = KFold(5, shuffle=True, random_state=0)
for idx_fold, (idx_train, idx_test) in enumerate(cv.split(interactions_full_df)):
    interactions_train_df = interactions_full_df.iloc[idx_train]
    interactions_test_df = interactions_full_df.iloc[idx_test]
    model_evaluator = GoEat.ModelEvaluator(interactions_full_df,interactions_train_df,interactions_test_df,food_df,17) 
    
    for idx_nfactor, nfactor in enumerate(nfactors):
        cf_preds_df = GoEat.users_items_svd(interactions_train_df, nfactors = nfactor)
        cf_model = GoEat.CFRecommender(cf_preds_df, food_df)
        with HiddenPrints():
            global_metrics, detailed_results_df = model_evaluator.evaluate_model(cf_model)
        
        count = count + 1
        if count % 10 == 0:
            endtime = time.time() - start_time
            
            percent = round(count/total_length*100,2)
            print('%d percent done(%f seconds)'%(percent,endtime))
            
            approx_time = (endtime/count*total_length - endtime)/60
            
            print('approx. %f minute left'%(round(approx_time)))
        
        for idx_metric, metric in enumerate(metrics):
            accuracies[idx_nfactor][idx_metric][idx_fold] = global_metrics[metric]
        
nfactor_means=[]

for idx_nfactor in range(len(nfactors)):
    metric_means = []
    
    for idx_metric in range(len(metrics)):
        metric_mean = np.mean(accuracies[idx_nfactor][idx_metric])
        metric_means.append(metric_mean)
    
    nfactor_means.append(metric_means)
        


NfactorGridSearch_result = pd.DataFrame(nfactor_means,
             index=nfactors,columns=metrics)   

print('complete after %f seconds'%(time.time() - start_time))

NfactorGridSearch_result
# Out:
# 13 percent done(102.226536 seconds)
# approx. 11.000000 minute left
# 26 percent done(213.938695 seconds)
# approx. 10.000000 minute left
# 40 percent done(318.601713 seconds)
# approx. 8.000000 minute left
# 53 percent done(438.085086 seconds)
# approx. 6.000000 minute left
# 66 percent done(555.521930 seconds)
# approx. 5.000000 minute left
# 80 percent done(671.882656 seconds)
# approx. 3.000000 minute left
# 93 percent done(784.707876 seconds)
# approx. 1.000000 minute left
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-258ba9744e2a> in <module>()
#      57              index=nfactors,columns=metrics)
#      58
# ---> 59 print('complete after %f seconds'%(time.time() - startime))
#      60
#      61 NfactorGridSearch_result
#
# NameError: name 'startime' is not defined

# %%
NfactorGridSearch_result.to_csv('NfactorGridSearch_result.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()


NfactorGridSearch_result
# set width of bar
plt.figure(figsize=(20,10))
barWidth = 0.05

palettes = sns.color_palette("Paired", len(nfactors))
# set height of bar
for idx ,nfac in enumerate(nfactors):
    bar = NfactorGridSearch_result.loc[nfac].tolist()
    if idx == 0:
        r = np.arange(len(bar))
    else:
        r = [x + barWidth for x in r_previous]
    
    r_previous = r
    
    plt.bar(r, bar, color=palettes[idx], width=barWidth, edgecolor='white', label=str(nfac)+' factors')
    
plt.xlabel('group', fontweight='bold',fontsize =15)
plt.xticks([r + barWidth for r in range(len(bar))], ['Recall@5','Recall@10','NDCG@5','NDCG@10'],fontsize= 15)
#plt.ylim(0.85,1)
plt.title('SVD Factors Comparision\n',fontsize = 20)
# Create legend & Show graphic
plt.legend()
plt.show()
plt.savefig('SVDFactorsComparision.png')

# %%
cf_model = GoEat.CFRecommender(cf_preds_df, food_df)
cb_model = GoEat.CBRecommender(food_df,user_profiles,tfidf_matrix)
hybrid_model_product = GoEat.HybridRecommender(cb_model, cf_model, food_df)
hybrid_model_harmonic = GoEat.HybridRecommender(cb_model, cf_model, food_df, method='harmonic')
model_evaluator = GoEat.ModelEvaluator(interactions_full_df,interactions_train_df,interactions_test_df,food_df,17) 

models = [cb_model,cf_model,hybrid_model_product,hybrid_model_harmonic]

# %%
from sklearn.model_selection import KFold

cf_model = GoEat.CFRecommender(cf_preds_df, food_df)
cb_model = GoEat.CBRecommender(food_df,user_profiles,tfidf_matrix)
hybrid_model_product = GoEat.HybridRecommender(cb_model, cf_model, food_df)
hybrid_model_harmonic = GoEat.HybridRecommender(cb_model, cf_model, food_df, method='harmonic')
model_evaluator = GoEat.ModelEvaluator(interactions_full_df,interactions_train_df,interactions_test_df,food_df,17) 

models = [cb_model,cf_model,hybrid_model_product,hybrid_model_harmonic]
model_names = ['Conten-based','Colaborative Filtering','Hybrid(product)','Hybrid(harmonic)']
metrics = ['recall@5','recall@10','ndcg@5','ndcg@10']

accuracies = np.zeros((len(models),len(metrics),5))
total_length = len(models)*5

count = 0
start_time = time.time()
cv = KFold(5, shuffle=True, random_state=0)
for idx_fold, (idx_train, idx_test) in enumerate(cv.split(interactions_full_df)):
    interactions_train_df = interactions_full_df.iloc[idx_train]
    interactions_test_df = interactions_full_df.iloc[idx_test]
    
    model_evaluator = GoEat.ModelEvaluator(interactions_full_df,interactions_train_df,interactions_test_df,food_df,17) 
    
    cf_preds_df = GoEat.users_items_svd(interactions_train_df, nfactors = 5)
    cf_model = GoEat.CFRecommender(cf_preds_df, food_df)
    models[1] = cf_model
    models[2] = hybrid_model_product = GoEat.HybridRecommender(models[0], models[1], food_df)
    models[3] = hybrid_model_harmonic = GoEat.HybridRecommender(models[0], models[1], food_df, method='harmonic')
    
    
    
    for idx_model, model in enumerate(models):
        
        with HiddenPrints():
            global_metrics, detailed_results_df = model_evaluator.evaluate_model(model)
        
        count = count + 1
        
        if count % 5 == 0:
            endtime = time.time() - start_time
            
            percent = round(count/total_length*100,2)
            print('%d percent done(%f seconds)'%(percent,endtime))
            
            approx_time = (endtime/count*total_length - endtime)/60
            
            print('approx. %f minute left'%(round(approx_time)))
        
        for idx_metric, metric in enumerate(metrics):
            accuracies[idx_model][idx_metric][idx_fold] = global_metrics[metric]
        
model_means=[]

for idx_model in range(len(models)):
    metric_means = []
    
    for idx_metric in range(len(metrics)):
        metric_mean = np.mean(accuracies[idx_model][idx_metric])
        metric_means.append(metric_mean)
    
    model_means.append(metric_means)            


kfold_result = pd.DataFrame(model_means,
             index=model_names,columns=metrics)   

print('complete after %f minutes'%((time.time() - start_time)/60))

kfold_result
# Out:
# 25 percent done(62.279397 seconds)
# approx. 3.000000 minute left
# 50 percent done(116.747693 seconds)
# approx. 2.000000 minute left
# 75 percent done(173.856918 seconds)
# approx. 1.000000 minute left
# 100 percent done(235.408264 seconds)
# approx. 0.000000 minute left
# complete after 3.923538 minutes
#                         recall@5  recall@10    ndcg@5   ndcg@10
# Conten-based            0.919324   0.981063  0.925259  0.893417
# Colaborative Filtering  0.993623   0.997585  0.881449  0.918775
# Hybrid(product)         0.996135   0.997295  0.947568  0.962953
# Hybrid(harmonic)        0.994203   0.997101  0.954039  0.967802

# %%
kfold_result.to_csv('kfold_result.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()


# set width of bar
plt.figure(figsize=(25,11))
barWidth = 0.1

palettes = sns.color_palette("Paired", len(models))
# set height of bar
for idx ,model_name in enumerate(model_names):
    bars = kfold_result.loc[model_name].tolist()
    if idx == 0:
        r = np.arange(len(bars))
    else:
        r = [x + barWidth for x in r_previous]
    
    r_previous = r
    
    plt.bar(r, bars, color=palettes[idx], width=barWidth, edgecolor='white', label=model_name)
    
    for r_value,value in zip(r,bars):
            plt.text(r_value-0.04, value+0.001, str(round(value,3)), color='black', fontweight='bold')
    
plt.xlabel('group', fontweight='bold',fontsize =15)
plt.xticks([r + barWidth for r in range(len(bars))], ['Recall@5','Recall@10','NDCG@5','NDCG@10'],fontsize= 15)
plt.ylim(0.87,1)
plt.title('K-fold Models Comparision\n',fontsize = 25)
# Create legend & Show graphic
plt.legend(loc = 'upper right',fontsize= 15)
plt.show()
plt.savefig('ModelsComparision.png')

# %%
new_user = GoEat.cold_start_question(999,food_df,10)
# Out:
# 당신은 샤브샤브을(를) 얼마나 좋아하십니까?
#
# 0 - 먹어본 적 없음
# 1 - 별로 좋아하지 않음
# 5 - 매우 좋아함
#
#  4
#
# 당신은 불고기을(를) 얼마나 좋아하십니까?
#
# 0 - 먹어본 적 없음
# 1 - 별로 좋아하지 않음
# 5 - 매우 좋아함
#
#  4
#
# 당신은 전을(를) 얼마나 좋아하십니까?
#
# 0 - 먹어본 적 없음
# 1 - 별로 좋아하지 않음
# 5 - 매우 좋아함
#
#  4
#
# 당신은 삼계탕을(를) 얼마나 좋아하십니까?
#
# 0 - 먹어본 적 없음
# 1 - 별로 좋아하지 않음
# 5 - 매우 좋아함
#
#  4
#
# 당신은 갈비찜을(를) 얼마나 좋아하십니까?
#
# 0 - 먹어본 적 없음
# 1 - 별로 좋아하지 않음
# 5 - 매우 좋아함
#
#  4
#
# 당신은 알탕을(를) 얼마나 좋아하십니까?
#
# 0 - 먹어본 적 없음
# 1 - 별로 좋아하지 않음
# 5 - 매우 좋아함
#
#  2
#
# 당신은 쌀국수을(를) 얼마나 좋아하십니까?
#
# 0 - 먹어본 적 없음
# 1 - 별로 좋아하지 않음
# 5 - 매우 좋아함
#
#  3
#
# 당신은 매운탕을(를) 얼마나 좋아하십니까?
#
# 0 - 먹어본 적 없음
# 1 - 별로 좋아하지 않음
# 5 - 매우 좋아함
#
#  2
#
# 당신은 부대찌개을(를) 얼마나 좋아하십니까?
#
# 0 - 먹어본 적 없음
# 1 - 별로 좋아하지 않음
# 5 - 매우 좋아함
#
#  5
#
# 당신은 돈까스을(를) 얼마나 좋아하십니까?
#
# 0 - 먹어본 적 없음
# 1 - 별로 좋아하지 않음
# 5 - 매우 좋아함
#
#  3

# %%
interactions_df_test = interactions_df.append(new_user,ignore_index=True)
interactions_full_df_test = interactions_df_test \
                    .groupby(['userId', 'foodId'])['eventStrength'].mean() \
                    .apply(GoEat.smooth_user_preference).reset_index()
cf_preds_df_test = GoEat.users_items_svd(interactions_full_df_test, nfactors = 20)
builder_test= GoEat.user_profiles_builder()
user_profiles_test = builder_test.build_users_profiles(interactions_full_df_test,food_df,tfidf_matrix)

# %%
cf_model_test = GoEat.CFRecommender(cf_preds_df_test, food_df)
cb_model_test = GoEat.CBRecommender(food_df,user_profiles_test,tfidf_matrix)
hybrid_model_test = GoEat.HybridRecommender(cb_model_test, cf_model_test, food_df)
hybrid_model_harmonic_test = GoEat.HybridRecommender(cb_model_test, cf_model_test, food_df,method='harmonic')

# %%
print('CF')
print(cf_model_test.recommend_items(999,topn=10,items_to_ignore=new_user.foodId.tolist(),verbose=True).foodName)
print('\nCB')
print(cb_model_test.recommend_items(999,topn=10,items_to_ignore=new_user.foodId.tolist(),verbose=True).foodName)
print('\nHybrid(product)')
print(hybrid_model_test.recommend_items(999,topn=10,items_to_ignore=new_user.foodId.tolist(),verbose=True).foodName)
print('\nHybrid(harmonic)')
print(hybrid_model_harmonic_test.recommend_items(999,topn=10,items_to_ignore=new_user.foodId.tolist(),verbose=True).foodName)
# Out:
# CF
# 0       갈비탕
# 1       햄버거
# 2    함박스테이크
# 3      닭도리탕
# 4       떡갈비
# 5        찜닭
# 6      비빔냉면
# 7       수제비
# 8       월남쌈
# 9        갈비
# Name: foodName, dtype: object
#
# CB
# 0     팟타이
# 1    뼈해장국
# 2     쭈꾸미
# 3     아구찜
# 4    제육볶음
# 5     물냉면
# 6      갈비
# 7    닭도리탕
# 8     비빔밥
# 9      초밥
# Name: foodName, dtype: object
#
# Hybrid(product)
# 0      닭도리탕
# 1        갈비
# 2    함박스테이크
# 3       비빔밥
# 4      뼈해장국
# 5      비빔냉면
# 6       갈비탕
# 7       월남쌈
# 8       물냉면
# 9      제육볶음
# Name: foodName, dtype: object
#
# Hybrid(harmonic)
# 0      닭도리탕
# 1        갈비
# 2       비빔밥
# 3      뼈해장국
# 4    함박스테이크
# 5       물냉면
# 6      제육볶음
# 7      비빔냉면
# 8       월남쌈
# 9       마라탕
# Name: foodName, dtype: object
